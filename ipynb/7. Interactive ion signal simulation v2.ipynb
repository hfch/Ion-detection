# %% [markdown]
# ### Import potentials and coordinates from HDF5 file

# %%
import h5py
import numpy as np
import pandas as pd
from scipy.interpolate import RegularGridInterpolator as rgi
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from numba import jit
import time
from interpolation.splines import LinearSpline, CubicSplines

# %%
#Potential field are stored in a HDF5 file
f=h5py.File('PA_v4.hdf5','r')

# %%
for name in f:
    print(name)
# Out:
# Coordinates
# Potential Arrays
# iselectrode

# %%
#coordinates x,y,z in unit of mm
x=f["Coordinates/X"].value/2.
y=f["Coordinates/Y"].value/2.
z=f["Coordinates/Z"].value/2.

# %% [markdown]
# ### Set electrodes potentials and calculate spatial potential values
# 19 electrodes are set to certain potentials to create electric field to ionize Rydberg atoms

# %%
#set values of 19 electrodes, for ionization field of state n=30
#electrode_set_potentials=[187.*1.2,187.*1.2,-1.74,-278.*1.2,-0.114*1.2,-1900.,0.,3.97*1.2,-1.74*1.2,-278.*1.2,187.*1.2,187.*1.2,0.3*1.2,-278.*1.2,0.,0.,0.,0.318*1.2,0.307*1.2];
electrode_set_potentials=[195.,195.,-145.,-232.,-0.114,-1900.,0.,4.,0.3,-232.,195.,195.,-145.,-232.,0.,0.,0.,0.318,0.307];
electrode_set_potentials[9]=-250.
#electrode_set_potentials=[195.,195.,-150.,-545.,-0.114,-1900.,0.,4.,0.3,-545.,430.,430.,-150.,-545.,0.,0.,0.,0.318,0.307];

# %%
# generate potential by setting each electrode to its potential and adding up all electrodes' potential
potentials=np.zeros((len(x),len(y),len(z)))
for i in range(19):
    electroden=f["Potential Arrays/electrode"+str(i+1)].value
    potentials+=electrode_set_potentials[i]*electroden/10000.

# %% [markdown]
# ### Interpolate potential arrays and plot cross sections for comparison

# %%
#generate potential interpolation

from scipy.interpolate import RegularGridInterpolator as rgi
p_interpolation=rgi((x,y,z),potentials)

# %%
minlimit = [min(x), min(y), min(z)]
maxlimit = [max(x), max(y), max(z)]
orders = [len(x), len(y), len(z)]
p_interpolation2 = LinearSpline(minlimit, maxlimit, orders, potentials)
# Out:
# Setting
# [121 121 173]
# (121, 121, 173)

# %%
p_interpolation(np.array([102.5,102.5,65.]))
# Out:
# array([ 3.48480343])

# %% [markdown]
# ### Calculate single ion trajectory

# %% [markdown]
# Define velocity iteration function and trajectory iteration function for single ion.

# %% [markdown]
# MCP detector plane

# %%
phi=-82.*np.pi/180.
tmatrix=np.array([[np.cos(phi),0,-np.sin(phi)],
           [0,1,0],
           [np.sin(phi),0,np.cos(phi)]])

# %%
#center point of MCP plane
center=(tmatrix.dot(np.array([0.,0.,3.]))*2 + [247,205,214])/2
#c=(241+6*np.cos(phi) + np.tan(- phi)*(247 + 6*np.sin( - phi)))/2.
c=center[2] + np.tan(- phi)* center[0]
center, c
# Out:
# (array([ 126.47080421,  102.5       ,  107.4175193 ]), 1007.3040503174313)

# %%
#single ion's position and velocity iteration functions

@jit
def R(ri,vi,dt):                  #delta_t in unit of micro-second, displacement in unit of mm, v in unit of mm/us
    x_new=ri[0]+vi[0]*dt
    y_new=ri[1]+vi[1]*dt
    z_new=ri[2]+vi[2]*dt
    return np.array([x_new,y_new,z_new])

@jit
def Gradientforce(ri,vi,delta_t,dr):
    dvx=-100./(1.0364*87.) * (p_interpolation([ri[0]+dr,ri[1],ri[2]])[0]-p_interpolation([ri[0]-dr,ri[1],ri[2]])[0])/(dr*2) #- for positive ions, + for electrons
    dvy=-100./(1.0364*87.) * (p_interpolation([ri[0],ri[1]+dr,ri[2]])[0]-p_interpolation([ri[0],ri[1]-dr,ri[2]])[0])/(dr*2)
    dvz=-100./(1.0364*87.) * (p_interpolation([ri[0],ri[1],ri[2]+dr])[0]-p_interpolation([ri[0],ri[1],ri[2]-dr])[0])/(dr*2)
    vx_new=vi[0]+dvx * dt
    vy_new=vi[1]+dvy * dt
    vz_new=vi[2]+dvz * dt
    return np.array([vx_new,vy_new,vz_new])

def Gradientforce2(r,v,dt,dr):    
    dvx=-100./(1.0364*87.) * (p_interpolation([r[0]+dr,r[1],r[2]])-p_interpolation([r[0]-dr,r[1],r[2]]))/(dr*2) #- for positive ions, + for electrons
    dvy=-100./(1.0364*87.) * (p_interpolation([r[0],r[1]+dr,r[2]])-p_interpolation([r[0],r[1]-dr,r[2]]))/(dr*2)
    dvz=-100./(1.0364*87.) * (p_interpolation([r[0],r[1],r[2]+dr])-p_interpolation([r[0],r[1],r[2]-dr]))/(dr*2)
    vx_new=v[0]+dvx * dt
    vy_new=v[1]+dvy * dt
    vz_new=v[2]+dvz * dt
    return np.array([vx_new,vy_new,vz_new])

#@jit
def ion_exist(r):
    ion_number=len(r)
    ion_condition=[0 for i in range(ion_number)]
    for j in range(ion_number):
        r_ionj=r[j]
        ion_condition[j]=(r_ionj>[x[1],y[1],z[1]]).all() and (r_ionj<[x[-3],y[-3],z[-3]]).all() and (r_ionj[2]-np.tan(phi)*r_ionj[0]<=c)
        
    return ion_condition

"""
#Function to calculate two ions coulombic force
def VCoul(ra,rb):
    #coulombic acceleration of Rb ion at ra, due to repulsion of Rb ion at rb
    distance=np.linalg.norm(ra-rb)
    coulf=1.595 * 1.e-6 /distance**2
    return (ra-rb)*coulf/distance
"""
    
@jit
def VCoul(index,r_iter,ion_condition):
    r_origin=r_iter[index]
    ion_number=len(r_iter)
    force=np.zeros((1,3))
    for i in range(ion_number):
        if (i!=index and ion_condition[i]):
            distance=np.linalg.norm(r_origin - r_iter[i])
            coulf=1.595 * 1.e-6 / distance**2
            force += (r_origin - r_iter[i]) * coulf/distance
    return force[0]
    
    
@jit
def cross_ratio(r_n,r_iter,count,dt):
    x1=r_n[0]
    z1=r_n[2]
    x2=r_iter[0]
    z2=r_iter[2]
    a=np.array([[np.tan(-phi),1.],[(z2-z1)/(x1-x2),1]])
    b=np.array([c,(x1*z2-x2*z1)/(x1-x2)])
    
    r_p= np.linalg.solve(a,b)
    ratio=(r_p[0]-r_n[0])/(r_iter[0]-r_n[0])
    count += ratio
    y_p= r_n[1] +(r_iter[1]-r_n[1])*ratio
    t=count*dt
    r_new= np.array([np.sign(r_p[1]-center[2]) * np.sqrt((r_p[0]-center[0])**2 + (r_p[1]-center[2])**2),y_p-center[1],t])
    return r_new

# %%
@jit
def trajectory2(r_init,v_init,dt):
    r_iter=r_init
    v_iter=v_init 
    r_n=r_init
    count=0              #no appending?
    while (r_iter>[x[1],y[1],z[1]]).all() and (r_iter<[x[-2],y[-2],z[-2]]).all() and (r_iter[2]-np.tan(phi)*r_iter[0]<=c):
        # while loop condition: ion still in effective volume, and not hit the plane
        r_n=r_iter
        v_iter=Gradientforce(r_iter,v_iter,dt,dr)
        r_iter=R(r_iter,v_iter,dt)
        count+=1
        if count*dt>20:
            break
        
    x1=r_n[0]
    z1=r_n[2]
    x2=r_iter[0]
    z2=r_iter[2]
    a=np.array([[np.tan(-phi),1.],[(z2-z1)/(x1-x2),1]])
    b=np.array([c,(x1*z2-x2*z1)/(x1-x2)])
    
    r_p= np.linalg.solve(a,b)
    v=v_iter
    ratio=(r_iter[0]-r_p[0])/(r_iter[0]-r_n[0])
    count += ratio
    y_p= r_n[1] +(r_iter[1]-r_n[1])*ratio
    t=count*dt
    r_new= [np.sign(r_p[1]-center[2]) * np.sqrt((r_p[0]-center[0])**2 + (r_p[1]-center[2])**2),y_p-center[1],t]
    
    return [r_new,v]

# %% [markdown]
# Test ion_exist() and VCoul() functions

# %%
r_test=np.zeros((1000,3))
r0=np.array([94.5,102.5,54.5])
for i in range(len(r_test)):
    r_test[i]=r0 + [10*i, 0,0]
conditiontest=ion_exist(r_test)

# %% [markdown]
# **Distance step when calculating gradient has significant fluence on the trajectories**

# %%
dr=0.5       #dr[mm] is used when calculating gradients
dt=0.01     #dt[us]

# %%
def trajectories_ions(r_init,v_init,dt):
    ion_number=len(r_init)
    count=np.zeros(ion_number)
    r_iter=np.zeros((ion_number,3))
    r_n=np.zeros((ion_number,3))
    r_iter=r_init
    v_iter=v_init
    r_n=np.zeros((ion_number,3))
    
    #no appending?
    global condition
    condition = ion_exist(r_iter)
    sequence=[k for k in range(ion_number)]
    while any(condition):
        # while loop condition: ion still in effective volume, and not hit the plane
        """if iondistance<0.01:
            dt=0.0001
        else:
            dt=0.01"""
        t0=time.time()
        for i in sequence:
            if condition[i]:
                r_n[i]=np.array(r_iter[i])
                v_iter[i] = Gradientforce(r_iter[i],v_iter[i],dt,dr) + VCoul(i,r_iter,condition) * dt
                r_iter[i]=R(r_iter[i],v_iter[i],dt)
                count[i] += 1
            #print r_iter[0]
        if max(count * dt)>15:
            break
        t1=time.time()
        condition=ion_exist(r_iter)
        t2=time.time()
        print(r_iter[0])
        
    #map coordinates into detector plane coordinate
    r_final=np.zeros((ion_number,3))
    for k in range(ion_number):
        r_final[k]=cross_ratio(r_n[k],r_iter[k],count[k],dt)
    v_final=v_iter
    #print r_final
    #displacement=np.array(r_new1) - np.array(r_new2)
    ionsituation=np.concatenate((r_final,v_final),axis=1)
    print(r_final)
    return r_final

# %%
# 96.8  102.5   66.
#96.9,102.5,66.05
xc=np.linspace(96.9 - 0.05,96.9 + 0.05,11)
yc=np.linspace(102.5 - 0.01,102.5 + 0.01,5)
zc=np.linspace(66.05 - 0.01,66.05 + 0.01,5)
startpoints=np.zeros((len(xc)*len(yc)*len(zc),3))
finalpoints=np.zeros((len(xc)*len(yc)*len(zc),3))
v=np.zeros((len(xc)*len(yc)*len(zc),3))
ind=0
tstart=time.time()
for i in xc:
    for j in yc:
        for k in zc:
            startpoints[ind]=np.array([i,j,k])
            ind += 1

tend=time.time()
print(tend-tstart)
print(len(startpoints))

#startpoints
# Out:
# 0.0
# 275

# %%
# generate potential by setting each electrode to its potential and adding up all electrodes' potential
electrode_set_potentials[9]=-350.
potentials=np.zeros((len(x),len(y),len(z)))
for i in range(19):
    electroden=f["Potential Arrays/electrode"+str(i+1)].value
    potentials+=electrode_set_potentials[i]*electroden/10000.
p_interpolation=rgi((x,y,z),potentials)

# %%
singlefinals=np.zeros((len(startpoints),3))
v0=np.array([0,0,0])
tstart1=time.time()
for i in range(len(startpoints)):
    [singlefinals[i],v[i]]=trajectory2(startpoints[i],v0,dt)

tend1=time.time()
print((tend1-tstart1)/60.)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\numba\errors.py in new_error_context(fmt_, *args, **kwargs)
#     242     try:
# --> 243         yield
#     244     except NumbaError as e:
#
# D:\Anaconda3\lib\site-packages\numba\lowering.py in lower_block(self, block)
#     199                                    loc=self.loc, errcls_=defaulterrcls):
# --> 200                 self.lower_inst(inst)
#     201
#
# D:\Anaconda3\lib\site-packages\numba\objmode.py in lower_inst(self, inst)
#      64         if isinstance(inst, ir.Assign):
# ---> 65             value = self.lower_assign(inst)
#      66             self.storevar(value, inst.target.name)
#
# D:\Anaconda3\lib\site-packages\numba\objmode.py in lower_assign(self, inst)
#     158         elif isinstance(value, ir.Expr):
# --> 159             return self.lower_expr(value)
#     160         elif isinstance(value, ir.Global):
#
# D:\Anaconda3\lib\site-packages\numba\objmode.py in lower_expr(self, expr)
#     241         elif expr.op == 'call':
# --> 242             argvals = [self.loadvar(a.name) for a in expr.args]
#     243             fn = self.loadvar(expr.func.name)
#
# D:\Anaconda3\lib\site-packages\numba\objmode.py in <listcomp>(.0)
#     241         elif expr.op == 'call':
# --> 242             argvals = [self.loadvar(a.name) for a in expr.args]
#     243             fn = self.loadvar(expr.func.name)
#
# D:\Anaconda3\lib\site-packages\numba\objmode.py in loadvar(self, name)
#     519         # If this raises then the live variables analysis is wrong
# --> 520         assert name in self._live_vars, name
#     521         ptr = self.varmap[name]
#
# AssertionError: count.1
#
# During handling of the above exception, another exception occurred:
#
# LoweringError                             Traceback (most recent call last)
# <ipython-input-228-254bb3e0fddd> in <module>()
#       3 tstart1=time.time()
#       4 for i in range(len(startpoints)):
# ----> 5     [singlefinals[i],v[i]]=trajectory2(startpoints[i],v0,dt)
#       6
#       7 tend1=time.time()
#
# D:\Anaconda3\lib\site-packages\numba\dispatcher.py in _compile_for_args(self, *args, **kws)
#     283                 argtypes.append(self.typeof_pyval(a))
#     284         try:
# --> 285             return self.compile(tuple(argtypes))
#     286         except errors.TypingError as e:
#     287             # Intercept typing error that may be due to an argument
#
# D:\Anaconda3\lib\site-packages\numba\dispatcher.py in compile(self, sig)
#     529
#     530             self._cache_misses[sig] += 1
# --> 531             cres = self._compiler.compile(args, return_type)
#     532             self.add_overload(cres)
#     533             self._cache.save_overload(sig, cres)
#
# D:\Anaconda3\lib\site-packages\numba\dispatcher.py in compile(self, args, return_type)
#      78                                       impl,
#      79                                       args=args, return_type=return_type,
# ---> 80                                       flags=flags, locals=self.locals)
#      81         # Check typing error if object mode is used
#      82         if cres.typing_error is not None and not flags.enable_pyobject:
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library)
#     723     pipeline = Pipeline(typingctx, targetctx, library,
#     724                         args, return_type, flags, locals)
# --> 725     return pipeline.compile_extra(func)
#     726
#     727
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in compile_extra(self, func)
#     367                 raise e
#     368
# --> 369         return self.compile_bytecode(bc, func_attr=self.func_attr)
#     370
#     371     def compile_bytecode(self, bc, lifted=(), lifted_from=None,
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in compile_bytecode(self, bc, lifted, lifted_from, func_attr)
#     376         self.lifted_from = lifted_from
#     377         self.func_attr = func_attr
# --> 378         return self._compile_bytecode()
#     379
#     380     def compile_ir(self, interp, lifted=(), lifted_from=None,
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in _compile_bytecode(self)
#     688         """
#     689         assert self.interp is None
# --> 690         return self._compile_core()
#     691
#     692     def _compile_ir(self):
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in _compile_core(self)
#     675
#     676         pm.finalize()
# --> 677         res = pm.run(self.status)
#     678         if res is not None:
#     679             # Early pipeline completion
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in run(self, status)
#     255                     # No more fallback pipelines?
#     256                     if is_final_pipeline:
# --> 257                         raise patched_exception
#     258                     # Go to next fallback pipeline
#     259                     else:
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in run(self, status)
#     247                 try:
#     248                     event(stage_name)
# --> 249                     stage()
#     250                 except _EarlyPipelineCompletion as e:
#     251                     return e.result
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in stage_objectmode_frontend(self)
#     453         if self.flags.enable_looplift:
#     454             assert not self.lifted
# --> 455             cres = self.frontend_looplift()
#     456             if cres is not None:
#     457                 raise _EarlyPipelineCompletion(cres)
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in frontend_looplift(self)
#     444                               outer_flags, self.locals,
#     445                               lifted=tuple(loops), lifted_from=None,
# --> 446                               func_attr=self.func_attr)
#     447             return cres
#     448
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in compile_ir(typingctx, targetctx, interp, args, return_type, flags, locals, lifted, lifted_from, func_attr, library)
#     741     pipeline = Pipeline(typingctx, targetctx, library,
#     742                         args, return_type, flags, locals)
# --> 743     return pipeline.compile_ir(interp=interp, lifted=lifted, lifted_from=lifted_from, func_attr=func_attr)
#     744
#     745
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in compile_ir(self, interp, lifted, lifted_from, func_attr)
#     387
#     388         self._set_and_check_interp(interp)
# --> 389         return self._compile_ir()
#     390
#     391     def compile_internal(self, bc, func_attr=DEFAULT_FUNCTION_ATTRIBUTES):
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in _compile_ir(self)
#     695         """
#     696         assert self.interp is not None
# --> 697         return self._compile_core()
#     698
#     699
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in _compile_core(self)
#     675
#     676         pm.finalize()
# --> 677         res = pm.run(self.status)
#     678         if res is not None:
#     679             # Early pipeline completion
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in run(self, status)
#     255                     # No more fallback pipelines?
#     256                     if is_final_pipeline:
# --> 257                         raise patched_exception
#     258                     # Go to next fallback pipeline
#     259                     else:
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in run(self, status)
#     247                 try:
#     248                     event(stage_name)
# --> 249                     stage()
#     250                 except _EarlyPipelineCompletion as e:
#     251                     return e.result
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in stage_objectmode_backend(self)
#     593         """
#     594         lowerfn = self.backend_object_mode
# --> 595         self._backend(lowerfn, objectmode=True)
#     596
#     597         # Warn if compiled function in object mode and force_pyobject not set
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in _backend(self, lowerfn, objectmode)
#     570             self.library.enable_object_caching()
#     571
# --> 572         lowered = lowerfn()
#     573         signature = typing.signature(self.return_type, *self.args)
#     574         self.cr = compile_result(typing_context=self.typingctx,
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in backend_object_mode(self)
#     544                                      self.library,
#     545                                      self.interp,
# --> 546                                      self.flags)
#     547
#     548     def backend_nopython_mode(self):
#
# D:\Anaconda3\lib\site-packages\numba\compiler.py in py_lowering_stage(targetctx, library, interp, flags)
#     867     fndesc = funcdesc.PythonFunctionDescriptor.from_object_mode_function(interp)
#     868     lower = objmode.PyLower(targetctx, library, fndesc, interp)
# --> 869     lower.lower()
#     870     if not flags.no_cpython_wrapper:
#     871         lower.create_cpython_wrapper()
#
# D:\Anaconda3\lib\site-packages\numba\lowering.py in lower(self)
#     123         if self.generator_info is None:
#     124             self.genlower = None
# --> 125             self.lower_normal_function(self.fndesc)
#     126         else:
#     127             self.genlower = self.GeneratorLower(self)
#
# D:\Anaconda3\lib\site-packages\numba\lowering.py in lower_normal_function(self, fndesc)
#     158         # Init argument values
#     159         self.extract_function_arguments()
# --> 160         entry_block_tail = self.lower_function_body()
#     161
#     162         # Close tail of entry block
#
# D:\Anaconda3\lib\site-packages\numba\lowering.py in lower_function_body(self)
#     183             bb = self.blkmap[offset]
#     184             self.builder.position_at_end(bb)
# --> 185             self.lower_block(block)
#     186
#     187         self.post_lower()
#
# D:\Anaconda3\lib\site-packages\numba\lowering.py in lower_block(self, block)
#     198             with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     199                                    loc=self.loc, errcls_=defaulterrcls):
# --> 200                 self.lower_inst(inst)
#     201
#     202     def create_cpython_wrapper(self, release_gil=False):
#
# D:\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# D:\Anaconda3\lib\site-packages\numba\errors.py in new_error_context(fmt_, *args, **kwargs)
#     247     except Exception as e:
#     248         newerr = errcls(e).add_context(_format_msg(fmt_, args, kwargs))
# --> 249         six.reraise(type(newerr), newerr, sys.exc_info()[2])
#     250
#     251
#
# D:\Anaconda3\lib\site-packages\numba\six.py in reraise(tp, value, tb)
#     656             value = tp()
#     657         if value.__traceback__ is not tb:
# --> 658             raise value.with_traceback(tb)
#     659         raise value
#     660
#
# D:\Anaconda3\lib\site-packages\numba\errors.py in new_error_context(fmt_, *args, **kwargs)
#     241     errcls = kwargs.pop('errcls_', InternalError)
#     242     try:
# --> 243         yield
#     244     except NumbaError as e:
#     245         e.add_context(_format_msg(fmt_, args, kwargs))
#
# D:\Anaconda3\lib\site-packages\numba\lowering.py in lower_block(self, block)
#     198             with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     199                                    loc=self.loc, errcls_=defaulterrcls):
# --> 200                 self.lower_inst(inst)
#     201
#     202     def create_cpython_wrapper(self, release_gil=False):
#
# D:\Anaconda3\lib\site-packages\numba\objmode.py in lower_inst(self, inst)
#      63     def lower_inst(self, inst):
#      64         if isinstance(inst, ir.Assign):
# ---> 65             value = self.lower_assign(inst)
#      66             self.storevar(value, inst.target.name)
#      67
#
# D:\Anaconda3\lib\site-packages\numba\objmode.py in lower_assign(self, inst)
#     157             return val
#     158         elif isinstance(value, ir.Expr):
# --> 159             return self.lower_expr(value)
#     160         elif isinstance(value, ir.Global):
#     161             return self.lower_global(value.name, value.value)
#
# D:\Anaconda3\lib\site-packages\numba\objmode.py in lower_expr(self, expr)
#     240             return res
#     241         elif expr.op == 'call':
# --> 242             argvals = [self.loadvar(a.name) for a in expr.args]
#     243             fn = self.loadvar(expr.func.name)
#     244             args = self.pyapi.tuple_pack(argvals)
#
# D:\Anaconda3\lib\site-packages\numba\objmode.py in <listcomp>(.0)
#     240             return res
#     241         elif expr.op == 'call':
# --> 242             argvals = [self.loadvar(a.name) for a in expr.args]
#     243             fn = self.loadvar(expr.func.name)
#     244             args = self.pyapi.tuple_pack(argvals)
#
# D:\Anaconda3\lib\site-packages\numba\objmode.py in loadvar(self, name)
#     518         """
#     519         # If this raises then the live variables analysis is wrong
# --> 520         assert name in self._live_vars, name
#     521         ptr = self.varmap[name]
#     522         val = self.builder.load(ptr)
#
# LoweringError: Failed at object (object mode frontend)
# Failed at object (object mode backend)
# count.1
# File "<ipython-input-135-50678e18b6bd>", line 7
# [1] During: lowering "$221 = call $220(count.1, dt, r_iter, r_n, v_iter)" at <ipython-input-135-50678e18b6bd> (7)

# %%
# %matplotlib inline
plt.figure()
theta=np.linspace(0,2*np.pi,100)
plt.plot(7.25*np.sin(theta),7.25*np.cos(theta))
plt.axes().set_aspect('equal')
plt.plot(singlefinals[:,0],singlefinals[:,1],'r*')
plt.xlabel("x axis on MCP/mm")
plt.ylabel("y axis on MCP/mm")
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.title("final position map of 275 ions without interaction")
plt.show()

# %%
count, bins, ignored = plt.hist(singlefinals[:,2], 22, normed=True)
plt.xlabel("ions arrival time/us")
plt.ylabel("ion number")
plt.title("275 ions TOF without interaction")
plt.show()

# %%
ionfinalpoints=np.zeros((len(startpoints),3))
v=np.zeros((len(startpoints),3))

# %%
tstart2=time.time()
ionfinalpoints=trajectories_ions(startpoints,v,dt)
tend2=time.time()
print(tend2-tstart2)
# Out:
# [  96.85005869  102.48997515   66.04090928]
# [  96.85017616  102.48992559   66.04272798]
# [  96.85035263  102.48985156   66.04545638]
# [  96.85058841  102.48975347   66.04909498]
# [  96.85088396  102.48963189   66.05364452]
# [  96.85123955  102.48948794   66.05910715]
# [  96.85165778  102.48932235   66.06548441]
# [  96.85213974  102.48913578   66.0727777 ]
# [  96.8526863   102.48892889   66.08098817]
# [  96.85329823  102.48870236   66.0901168 ]
# [  96.8539763   102.48845683   66.10016445]
# [  96.85472126  102.48819295   66.11113189]
# [  96.85553387  102.4879114    66.12301983]
# [  96.85641488  102.48761283   66.13582895]
# [  96.85736502  102.48729789   66.14955984]
# [  96.85838502  102.48696719   66.16421309]
# [  96.85947557  102.48662134   66.1797892 ]
# [  96.86063737  102.48626088   66.19628864]
# [  96.86187111  102.48588635   66.21371186]
# [  96.86317746  102.48549826   66.23205925]
# [  96.86455711  102.48509708   66.25133122]
# [  96.86601074  102.48468332   66.27152813]
# [  96.867539    102.48425746   66.29265035]
# [  96.86914254  102.48381999   66.31469823]
# [  96.87082198  102.48337143   66.33767212]
#  [ -4.35537090e-01   6.49375917e-02   5.71795190e+00]
#  [ -5.83354067e-01   2.44329037e-01   5.83912343e+00]
#  [  6.01508745e+00   6.51145889e-01   2.01154608e+01]
#  [ -8.21003009e+00  -2.89585473e+00   1.22817509e+01]
#  [ -4.39082186e-01   3.10086990e-01   5.66034839e+00]
#  [ -4.36722528e-01   3.32939730e-01   5.72220754e+00]
#  [ -5.67510242e-01   5.65735939e-01   5.84121013e+00]
#  [ -2.84383060e+00   6.61600405e+00   1.33876432e+01]
#  [ -1.18310953e+00   2.38212349e+00   6.08256509e+00]
#  [ -4.57721516e-01   6.16771117e-01   5.67656769e+00]]
# 348.56699991226196

# %%
finalpoints_good=ionfinalpoints[np.linalg.norm(ionfinalpoints[:,:2],axis=1) < 7.25]
finalpoints_good
# Out:
# array([[  4.81391478,   5.09151407,  16.39726449],
#        [  7.07445814,   0.99598504,  16.55119401],
#        [  5.17609532,   0.34021703,  16.41132527],
#        [  4.83758382,  -0.06195384,  16.38808817],
#        [  5.71849418,  -3.6037691 ,  16.46518667],
#        [  5.89736892,  -2.46154245,  16.46740734],
#        [  4.50663659,  -0.83496806,  16.36737012]])

# %%
ionfinalpoints.shape, finalpoints_good.shape
# Out:
# ((275, 3), (7, 3))

# %%
# %matplotlib inline
plt.figure()
theta=np.linspace(0,2*np.pi,100)
plt.plot(7.25*np.sin(theta),7.25*np.cos(theta))
plt.axes().set_aspect('equal')
plt.plot(ionfinalpoints[:,0],ionfinalpoints[:,1],'r*')
plt.xlabel("x axis on MCP/mm")
plt.ylabel("y axis on MCP/mm")
#plt.xlim([-8,8])
#plt.ylim([-8,8])
plt.title("final position map of 267/275 ions with interaction")
plt.show()

# %%
"""
# %matplotlib notebook
newplot=plt.figure()
ionplot=newplot.add_subplot(111,projection='3d')
#mp.plot(MCP[:,0],MCP[:,1],MCP[:,2],label='MCP')
ionplot.plot(startpoints[:,0],startpoints[:,1],startpoints[:,2],'.')
#mp.plot(points[:,0],points[:,1],points[:,2])
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Start point, x:94.45 - 94.55, y:102.49 - 102.51, z:55.49 - 55.51 \n ion distance 5um")
plt.show()
"""
# Out:
# '\n%matplotlib notebook\nnewplot=plt.figure()\nionplot=newplot.add_subplot(111,projection=\'3d\')\n#mp.plot(MCP[:,0],MCP[:,1],MCP[:,2],label=\'MCP\')\nionplot.plot(startpoints[:,0],startpoints[:,1],startpoints[:,2],\'.\')\n#mp.plot(points[:,0],points[:,1],points[:,2])\nplt.xlabel("X")\nplt.ylabel("Y")\nplt.title("Start point, x:94.45 - 94.55, y:102.49 - 102.51, z:55.49 - 55.51 \n ion distance 5um")\nplt.show()\n'

# %%
# %matplotlib inline
count, bins, ignored = plt.hist(finalpoints_good[:,2], 50)
plt.xlabel("ions arrival time/us")
plt.ylabel("ion number")
plt.title("267/275 ions TOF with interaction")
plt.show()

# %% [markdown]
# Deflection Ring 2 voltage = -232V

# %%
electrode_set_potentials=[195.,195.,-145.,-232.,-0.114,-1900.,0.,4.,0.3,-232.,195.,195.,-145.,-232.,0.,0.,0.,0.318,0.307];

# %%
# 96.8  102.5   66.
#96.9,102.5,66.05
xc=np.linspace(96.9 - 0.05,96.9 + 0.05,11)
yc=np.linspace(102.5 - 0.01,102.5 + 0.01,5)
zc=np.linspace(66.05 - 0.01,66.05 + 0.01,5)
startpoints2=np.zeros((len(xc)*len(yc)*len(zc),3))
finalpoints2=np.zeros((len(xc)*len(yc)*len(zc),3))
v=np.zeros((len(xc)*len(yc)*len(zc),3))
ind=0
tstart=time.time()
for i in xc:
    for j in yc:
        for k in zc:
            startpoints2[ind]=np.array([i,j,k])
            ind += 1

tend=time.time()
print(tend-tstart)
print(len(startpoints2))

#startpoints
# Out:
# 0.0009999275207519531
# 275

# %%
startpoints
# Out:
# array([[ 126.38346108,  101.58313139,  109.88586893],
#        [ 126.45378902,  101.90689907,  110.08102797],
#        [ 126.18229879,  103.06769044,  110.07523221],
#        [ 126.19333988,  101.35596655,  109.87556232],
#        [ 126.44458173,  102.05925494,  109.93774683],
#        [ 126.15118112,  101.68648564,  109.81834438],
#        [ 126.12052689,  102.14053751,  110.06606151],
#        [ 126.39653082,  104.52306938,  110.24273552],
#        [ 126.47264797,  101.75844305,  109.89174056],
#        [ 126.31106228,  102.10273891,  109.99707167],
#        [ 126.39310065,  102.53098067,  109.77705625],
#        [ 126.31137154,  102.33905855,  110.07265315],
#        [ 107.53715776,   86.22066643,   86.16451171],
#        [ 126.39226865,  102.06012096,  109.87833333],
#        [ 126.25371786,  102.23534473,  109.98113517],
#        [ 126.66712788,  102.65930113,  109.85159388],
#        [ 126.46755146,  102.54595435,  110.0645312 ],
#        [ 126.43633432,  100.24990648,  110.09352684],
#        [ 126.39632963,  103.03185   ,  109.88242906],
#        [ 126.30699293,  102.40184293,  110.0112343 ],
#        [ 126.3689955 ,  102.96533758,  109.82792182],
#        [ 126.40108738,  102.80807634,  110.03117454],
#        [ 126.28695968,  101.73559365,  110.04005889],
#        [ 126.71921841,  103.39809036,  109.87898683],
#        [ 126.43720053,  102.58082054,  109.99588568],
#        [ 126.41492563,  101.56166273,  109.84186336],
#        [ 126.29000047,  101.72066141,  110.01972283],
#        [ 126.6250253 ,  102.83102713,  110.08180717],
#        [ 126.54925058,  101.3193583 ,  109.68246215],
#        [ 126.76835165,  101.7035688 ,  109.93562025],
#        [ 126.22670306,  101.73438175,  109.76034367],
#        [ 126.32841792,  101.97287013,  109.99883313],
#        [ 126.4645817 ,  102.70557554,  109.91974598],
#        [ 126.31026663,  103.32761806,  109.46434455],
#        [ 126.69547118,  102.03358989,  109.9504272 ],
#        [ 126.76877696,  102.4546159 ,  109.77189986],
#        [ 126.73513235,  102.51348666,  110.03355181],
#        [ 126.6890563 ,  101.97357622,  109.8842803 ],
#        [ 126.70803955,  102.37667047,  109.83810002],
#        [ 126.13098443,  102.39176818,  109.89977023],
#        [ 126.73545991,  102.69377492,  109.7771078 ],
#        [ 126.64117647,  102.77817837,  110.00958224],
#        [ 126.51564506,  101.55198264,  109.90314897],
#        [ 126.28949235,  101.95115809,  109.48976779],
fions=h5py.File('TOF and final position with Coulombic interaction.hdf5','w')

# %%
TOFv2=fions.create_group("new voltage set")

# %%
finalcoulv2=TOFv2.create_dataset("final points",(ionfinalpoints.shape),dtype=np.float64)
finalcoulv2[...]=ionfinalpoints

# %%
startcoul=TOFv2.create_dataset("startpoints",(startpoints.shape),dtype=np.float64)
startcoul[...]=startpoints

# %%
fcoul=h5py.File('TOF and final position with Coulombic interaction.hdf5','w')

# %%
startcoul=fcoul.create_dataset("startpoints",(startpoints.shape),dtype=np.float64)

# %%
startcoul[...]=startpoints

# %%
finalcoul=fcoul.create_dataset("finalpoints",(finalpoints.shape),dtype=np.float64)
finalcoul[...]=finalpoints

# %%
fnocoul=h5py.File('TOF and final position without Couloumbic interaction.hdf5','w')

# %%
single=fnocoul.create_dataset("single ions final position",(singlefinals.shape),dtype=np.float64)

# %%
v0=np.zeros((100,3))
r0=np.zeros((100,3))
for k in range(len(r0)):
    r0[k]=[94.5 + k*0.1,102.5,54.5]
#r0=np.array([[94.5,102.5,54.5],[94.6,102.5,54.5],[94.7,102.5,54.5],[94.8,102.5,54.5]])
tstart=time.time()
r=trajectories_ions(r0,v0,dt)
tend=time.time()
print r,tend-tstart
# Out:
# [[ 0.18829336  0.07690852  4.45376038]
#  [ 0.05391135  0.08748673  4.44320879]
#  [-0.07262028  0.0979      4.43302534]
#  [-0.19288363  0.10811478  4.42307097]
#  [-0.30193144  0.11810359  4.41349445]
#  [-0.3992394   0.12778341  4.40436299]
#  [-0.48707629  0.13710076  4.39575847]
#  [-0.56709355  0.14628521  4.38757263]
#  [-0.6336089   0.15531062  4.37977038]
#  [-0.68683687  0.16414294  4.37236991]
#  [-0.719545    0.17271789  4.36547806]
#  [-0.73730465  0.18100197  4.35924184]
#  [-0.75769785  0.1892606   4.35392753]
#  [-0.76707881  0.19739203  4.34897964]
#  [-0.78482101  0.20536316  4.34435681]
#  [-0.80398912  0.21300716  4.3395068 ]
#  [-0.83763186  0.22029878  4.33458917]
#  [-0.88079716  0.22740469  4.329504  ]
#  [-0.93059264  0.23418254  4.32354854]
#  [-0.99867372  0.24077771  4.31781273]
#  [-1.07005457  0.24711208  4.31219076]
#  [-1.15118889  0.25299205  4.30590794]
#  [-1.23979883  0.25881449  4.30018954]
#  [-1.32781134  0.2644488   4.29437629]
#  [-1.42037083  0.26988538  4.28862454]
#  [-1.50727853  0.27515801  4.28334964]
#  [-1.59727215  0.28005951  4.27773767]
#  [-1.67980983  0.28494058  4.27272935]
#  [-1.75627389  0.28964759  4.26761648]
#  [-1.8282727   0.2942395   4.26284762]
#  [-1.8901692   0.29860263  4.25804362]
#  [-1.94559998  0.30273343  4.25344365]
#  [-1.9966892   0.30675501  4.24887338]
#  [-2.03966268  0.31064943  4.24438618]
#  [-2.0834154   0.31441704  4.24002682]
#  [-2.11608648  0.31797081  4.23564918]
#  [-2.15140699  0.321317    4.23140757]
#  [-2.17436019  0.3245674   4.22720233]
#  [-2.20221216  0.3276954   4.22303825]
#  [-2.22287179  0.33076587  4.21915076]
#  array([ 62.59098621,   0.063188  ,  12.78745611]))

# %%
xc=np.linspace(94.5 - 0.05,94.5 + 0.05,21)
yc=np.linspace(102.5 - 0.01,102.5 + 0.01,5)
zc=np.linspace(55.5 - 0.01,55.5 + 0.01,5)
print xc
print yc
print zc
# Out:
# [ 94.45   94.455  94.46   94.465  94.47   94.475  94.48   94.485  94.49
#   94.495  94.5    94.505  94.51   94.515  94.52   94.525  94.53   94.535
#   94.54   94.545  94.55 ]
# [ 102.49   102.495  102.5    102.505  102.51 ]
# [ 55.49   55.495  55.5    55.505  55.51 ]

# %%
r0=np.array([102.5,102.5,65.])
v0=np.array([0.,0.,0.])

# %%
# %load_ext Cython

# %%
# %%cython
#
# cdef int a = 0
# for i in range(10):
#     a += i
# print(a)
# Out:
# ---------------------------------------------------------------------------
# DistutilsPlatformError                    Traceback (most recent call last)
# <ipython-input-37-45647f021d90> in <module>()
# ----> 1 get_ipython().run_cell_magic('cython', '', '\ncdef int a = 0\nfor i in range(10):\n    a += i\nprint(a)')
#
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-125> in cython(self, line, cell)
#
# D:\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# D:\Anaconda3\lib\site-packages\Cython\Build\IpythonMagic.py in cython(self, line, cell)
#     289             build_extension.build_temp = os.path.dirname(pyx_file)
#     290             build_extension.build_lib  = lib_dir
# --> 291             build_extension.run()
#     292             self._code_cache[key] = module_name
#     293
#
# D:\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     336
#     337         # Now actually compile and link everything.
# --> 338         self.build_extensions()
#     339
#     340     def check_extensions_list(self, extensions):
#
# D:\Anaconda3\lib\distutils\command\build_ext.py in build_extensions(self)
#     445             self._build_extensions_parallel()
#     446         else:
# --> 447             self._build_extensions_serial()
#     448
#     449     def _build_extensions_parallel(self):
#
# D:\Anaconda3\lib\distutils\command\build_ext.py in _build_extensions_serial(self)
#     470         for ext in self.extensions:
#     471             with self._filter_build_errors(ext):
# --> 472                 self.build_extension(ext)
#     473
#     474     @contextlib.contextmanager
#
# D:\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     530                                          debug=self.debug,
#     531                                          extra_postargs=extra_args,
# --> 532                                          depends=ext.depends)
#     533
#     534         # XXX outdated variable, kept here in case third-part code
#
# D:\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     304
#     305         if not self.initialized:
# --> 306             self.initialize()
#     307         compile_info = self._setup_compile(output_dir, macros, include_dirs,
#     308                                            sources, depends, extra_postargs)
#
# D:\Anaconda3\lib\distutils\_msvccompiler.py in initialize(self, plat_name)
#     197         plat_spec = PLAT_TO_VCVARS[plat_name]
#     198
# --> 199         vc_env = _get_vc_env(plat_spec)
#     200         if not vc_env:
#     201             raise DistutilsPlatformError("Unable to find a compatible "
#
# D:\Anaconda3\lib\distutils\_msvccompiler.py in _get_vc_env(plat_spec)
#      83     vcvarsall, vcruntime = _find_vcvarsall(plat_spec)
#      84     if not vcvarsall:
# ---> 85         raise DistutilsPlatformError("Unable to find vcvarsall.bat")
#      86
#      87     try:
#
# DistutilsPlatformError: Unable to find vcvarsall.bat

# %%
t0 = time.time()
r_iter = startpoints
v_iter = np.zeros((len(startpoints),3))
r_n = np.zeros((len(startpoints),3))
condition=ion_exist(startpoints)
count = np.zeros(len(startpoints))
r_n=startpoints
#v_iter[i] += VCoul(i,r_iter,condition) * dt
for i in range(275):
    
    if condition[i]:
        
        v_iter[i]=Gradientforce(np.array(r_iter[i]),np.array(v_iter[i]),dt,dr)
        r_iter[i]=R(r_iter[i],v_iter[i],dt)
        count[i] += 1
        #print r_iter[0]

condition=ion_exist(r_iter)

# %%
# %timeit Gradientforce(np.array(r_iter[i]),np.array(v_iter[i]),dt,dr)
# Out:
# 1000 loops, best of 3: 1.01 ms per loop

# %%
Gradientforce(np.array(r_iter[i]),np.array(v_iter[i]),dt,dr)
# Out:
# array([ 0.01534026,  0.00021232,  0.18502047])

# %%
# %timeit Gradientforce2(np.array(r_iter[i]),np.array(v_iter[i]),dt,dr)
# Out:
# 1000 loops, best of 3: 1.01 ms per loop

# %%
# %timeit Gradientforce3(np.array(r_iter[i]),np.array(v_iter[i]),dt,dr)
# Out:
# 10000 loops, best of 3: 51.4 µs per loop

# %%
Gradientforce3(np.array(r_iter[i]),np.array(v_iter[i]),dt,dr)
# Out:
# array([ 0.01534086,  0.00021237,  0.18502034])

# %%
# %timeit condition = ion_exist(startpoints)
# Out:
# 100 loops, best of 3: 2.58 ms per loop

# %%
# %timeit Gradientforce(startpoints[10],np.zeros(3),dt,dr)
# Out:
# 1000 loops, best of 3: 999 µs per loop

# %%
from scipy import spatial

# %%
A = np.random.random((10,2))*100

# %%
pt = [6,30]

# %%
A[spatial.KDTree(A).query(pt)[1]]
# Out:
# array([  2.88361217,  37.84305496])

# %%
from numba import guvectorize, float64, jit, uint32, int64

# %%
@jit(uint32(float64[:],float64))
def find_nearest(a, a0):
    idx = np.abs(a-a0).argmin()
    return idx

# %%
type(find_nearest(x,93.2))
# Out:
# int

# %%
# %timeit find_nearest(np.array([93.2,92.4,65.2]))
# Out:
# The slowest run took 36.18 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 8.69 µs per loop

# %%
@jit
def p_interpolate(ri):
    idxx = find_nearest(x, ri[0])
    idxy = find_nearest(y, ri[1])
    idxz = find_nearest(z, ri[2])
    x0 = x[idxx]
    x1 = x[idxx+1]
    y0 = y[idxy]
    y1 = y[idxy+1]
    z0 = z[idxz]
    z1 = z[idxz+1]
    xd = (ri[0] - x0)/(x1 - x0)
    yd = (ri[1] - y0)/(y1 - y0)
    zd = (ri[2] - z0)/(z1 - z0)
    c00 = (1 - xd) * potentials[idxx,idxy,idxz] + xd * potentials[idxx+1,idxy,idxz]
    c01 = (1 - xd) * potentials[idxx,idxy,idxz+1] + xd * potentials[idxx+1,idxy,idxz+1]
    c10 = (1 - xd) * potentials[idxx,idxy+1,idxz] + xd * potentials[idxx+1,idxy+1,idxz]
    c11 = (1 - xd) * potentials[idxx,idxy+1,idxz+1] + xd * potentials[idxx+1,idxy+1,idxz+1]
    c0 = c00*(1-yd) + c10 * yd
    c1 = c01*(1-yd) + c11 * yd
    fp = c0*(1-zd) + c1*zd
    return fp

# %%
@jit
def Gradientforce3(ri,vi,delta_t,dr):
    dvx=-100./(1.0364*87.) * (p_interpolate([ri[0]+dr,ri[1],ri[2]])-p_interpolate([ri[0]-dr,ri[1],ri[2]]))/(dr*2) #- for positive ions, + for electrons
    dvy=-100./(1.0364*87.) * (p_interpolate([ri[0],ri[1]+dr,ri[2]])-p_interpolate([ri[0],ri[1]-dr,ri[2]]))/(dr*2)
    dvz=-100./(1.0364*87.) * (p_interpolate([ri[0],ri[1],ri[2]+dr])-p_interpolate([ri[0],ri[1],ri[2]-dr]))/(dr*2)
    vx_new=vi[0]+dvx * dt
    vy_new=vi[1]+dvy * dt
    vz_new=vi[2]+dvz * dt
    return np.array([vx_new,vy_new,vz_new])

# %%
Gradientforce3(np.array(r_iter[i]),np.array(v_iter[i]),dt,dr)
# Out:
# array([ 0.01534086,  0.00021237,  0.18502034])

# %%
forcex3 = [Gradientforce3(i, np.ones(3), dt, dr) for i in startpoints2]
forcex1 = [Gradientforce(j, np.ones(3), dt, dr) for j in startpoints2]

# %%
comparex = [np.abs(forcex3[i][0]-forcex1[i][0]) for i in range(len(forcex3))]

# %%
comparex
# Out:
# [1.8416960110290148e-06,
#  1.8244840156445008e-06,
#  1.8072720202599868e-06,
#  1.7900600250975174e-06,
#  1.7728480297130034e-06,
#  1.8589048818018483e-06,
#  1.8419018672499732e-06,
#  1.8248988524760534e-06,
#  1.8078958379241783e-06,
#  1.7908928233723032e-06,
#  1.8761137527967264e-06,
#  1.859319718633401e-06,
#  1.8425256849141647e-06,
#  1.8257316507508392e-06,
#  1.8089376170316029e-06,
#  1.8760856090871414e-06,
#  1.8592924273530542e-06,
#  1.8424992453969224e-06,
#  1.8257060634407907e-06,
#  1.8089128819287481e-06,
#  1.876057465599601e-06,
#  1.8592651358506629e-06,
#  1.8424728061017248e-06,
#  1.8256804761307421e-06,
#  1.8088881463818041e-06,
#  1.716661714779022e-06,
#  1.7005700234662413e-06,
#  1.6844783323755053e-06,
#  1.6683866410627246e-06,
#  1.652294949749944e-06,
#  1.7338506086428396e-06,
#  1.717967547332222e-06,
#  1.7020844857995598e-06,
#  1.6862014242668977e-06,
#  1.6703183629562801e-06,
#  1.7510395025066572e-06,
#  1.7353650707541135e-06,
#  1.7196906392236144e-06,
#  1.7040162074710707e-06,
#  1.6883417759405717e-06,
#  1.7510132352960284e-06,
#  1.7353395989072595e-06,
#  1.7196659622964461e-06,
#  1.7039923259076772e-06,
#  1.688318689740953e-06,
#  1.7509869678633549e-06,
#  1.7353141268383609e-06,
#  1.7196412858133669e-06,
#  1.7039684445663283e-06,
#  1.6882956033192897e-06,
#  1.5916274187510737e-06,
#  1.5766560315100264e-06,
#  1.5616846444910237e-06,
#  1.5467132572499764e-06,
#  1.5317418702309737e-06,
#  1.6087963354838308e-06,
#  1.5940332271924262e-06,
#  1.5792701191230663e-06,
#  1.5645070106096171e-06,
#  1.5497439023182125e-06,
#  1.6259652522165879e-06,
#  1.6114104228748261e-06,
#  1.5968555935330642e-06,
#  1.5823007639692577e-06,
#  1.5677459346274958e-06,
#  1.6259408612828707e-06,
#  1.6113867702394202e-06,
#  1.5968326791959697e-06,
#  1.5822785885966084e-06,
#  1.5677244975531579e-06,
#  1.6259164703491535e-06,
#  1.611363117826059e-06,
